# %%
pip install pymongo
# Out:
# ...
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/731.2 kB ? eta -:--:--
#    --------------------------- ---------- 524.3/731.2 kB 882.6 kB/s eta 0:00:01
#    -------------------------------------- 731.2/731.2 kB 967.2 kB/s eta 0:00:00
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

AZURE_MAPS_API_KEY = "CrmTiMSTPszl8bcBBnRj99CJuSCMIAjswlakRYfcK5WY9BHl4bnxJQQJ99BCACYeBjFS5Jc4AAAgAZMPhJCW"  # Replace with your actual key
origin = "18.5204,73.8567"  # Pune
destination = "19.0760,72.8777"  # Mumbai

url = f"https://atlas.microsoft.com/route/directions/json?subscription-key={AZURE_MAPS_API_KEY}&api-version=1.0&query={origin}:{destination}"

response = requests.get(url)
data = response.json()

print(data)
import requests

AZURE_MAPS_API_KEY = "YOUR_AZURE_SUBSCRIPTION_KEY"  # Replace with your actual key
origin = "18.5204,73.8567"  # Pune
destination = "19.0760,72.8777"  # Mumbai

url = f"https://atlas.microsoft.com/route/directions/json?subscription-key={AZURE_MAPS_API_KEY}&api-version=1.0&query={origin}:{destination}"

response = requests.get(url)
data = response.json()

print(data)
# Out:
# {'formatVersion': '0.0.12', 'routes': [{'summary': {'lengthInMeters': 140178, 'travelTimeInSeconds': 10046, 'trafficDelayInSeconds': 0, 'trafficLengthInMeters': 0, 'departureTime': '2025-03-01T17:15:49+05:30', 'arrivalTime': '2025-03-01T20:03:15+05:30'}, 'legs': [{'summary': {'lengthInMeters': 140178, 'travelTimeInSeconds': 10046, 'trafficDelayInSeconds': 0, 'trafficLengthInMeters': 0, 'departureTime': '2025-03-01T17:15:49+05:30', 'arrivalTime': '2025-03-01T20:03:15+05:30'}, 'points': [{'latitude': 18.52041, 'longitude': 73.85685}, {'latitude': 18.52064, 'longitude': 73.85684}, {'latitude': 18.52066, 'longitude': 73.85729}, {'latitude': 18.52069, 'longitude': 73.85781}, {'latitude': 18.52087, 'longitude': 73.85789}, {'latitude': 18.52094, 'longitude': 73.85796}, {'latitude': 18.52096, 'longitude': 73.85801}, {'latitude': 18.52099, 'longitude': 73.8581}, {'latitude': 18.52118, 'longitude': 73.85816}, {'latitude': 18.52138, 'longitude': 73.85819}, {'latitude': 18.52145, 'longitude': 73
# ...
